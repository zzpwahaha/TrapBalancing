# %%
import sys
sys.path.append('../')
sys.path.append('../3rd_Party/Vimba_4.2/VimbaPython/Source')
sys.path.append('C:\Chimera\B240_data_analysis\Library\ChimeraGenTools')
from AnalysisHelpers import findAtomLocs
from mako_camera import mako_camera
import numpy as np
import matplotlib.pyplot as plt

# %%
img_avg = np.loadtxt("../test/img_avg_test.txt")

# %%
p = plt.pcolormesh(img_avg)
plt.colorbar(p)

# %%
maximaLocs = findAtomLocs(img_avg, window=None, neighborhood_size=50., threshold=50, sort='MatchArray', debug_plot=True,n_cluster_row=2,
                            advanced_option = dict({"active":False, "image_threshold":100, "score_threshold":10}))
print(maximaLocs)
# Out:
# Found 18 Maxima.
# [[280, 277], [311, 277], [353, 277], [406, 277], [469, 277], [542, 277], [626, 277], [721, 277], [827, 277], [282, 593], [314, 593], [356, 593], [408, 593], [471, 593], [544, 593], [629, 593], [724, 593], [829, 593]]

# %%
print(repr(maximaLocs))
# Out:
# [[216, 313], [247, 313], [289, 313], [342, 313], [405, 313], [478, 313], [562, 313], [657, 313], [763, 313], [218, 629], [250, 629], [292, 629], [344, 629], [407, 629], [481, 629], [565, 629], [660, 629], [765, 629]]
